# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# # 실습 내용
#
# - Sample 데이터를 만들어 KNN에 대해 이해합니다.

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# # 1.데이터 준비
#
# - 학습용 데이터를 만들고 데이터 분포를 확인합니다.

# %%
# 데이터 만들기
np.random.seed(12)
x = np.random.randint(10, 51, (50, 2))
y = np.random.randint(0, 2, 50)
x = x * [1, 100]

# 데이터 분포 시각화
plt.figure(figsize=(8, 8))
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, s=100)
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# # 2.모델링
#
# - KNN 알고리즘으로 모델을 만들고 학습합니다.
# - 이웃 개수(n_neighbors)는 3으로 설정합니다.

# %%
# 불러오기
from sklearn.neighbors import KNeighborsClassifier

# 선언하기
model = KNeighborsClassifier(n_neighbors=3)

# 학습하기
model.fit(x, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # 3.우리별 색깔은?
#
# - 가장 가까운 3개의 이웃에게 물었습니다.
# - **"이웃님들 우리별은 무슨 색인가요?"**

# %%
# 우리별 자리
OUR_STAR = np.array([[26.5, 3200]])

# 기본 데이터
plt.figure(figsize=(8, 8))
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, s=100)

# 별 표시
star = OUR_STAR
sns.scatterplot(x=star[:,0], y=star[:,1], 
                marker='*', 
                color='k', 
                s=800)

plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# - **퀴즈!** 자신의 색깔을 찾지 못해 검게 변한 우리별 색깔은 무엇일까요?

# %% [markdown]
# # 4.우리별 색깔 확인
#
# - 우리가 예상한 색깔이 맞는지 확인합니다.

# %%
# 기본 데이터
plt.figure(figsize=(8, 8))
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, s=100)

# 별 색깔 확인
y_pred = model.predict(star)
star_color = 'b' if y_pred == 0 else 'r'

# 별 표시
sns.scatterplot(x=star[:,0], y=star[:,1], 
                marker='*', 
                color=star_color, 
                s=800)

plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# - 아하!우리별은 따뜻한 **<font color='red'>빨간색</font>** 이었네요!

# %% [markdown]
# # 5.우리별 이웃 확인
#
# - 고마운 마음을 전하기 위해 파란색을 찾아준 이웃을 확인합니다.

# %%
# 별 이웃 찾기
star_neighbor=[]
for n in model.kneighbors(star)[1].ravel():
    star_neighbor.append(x[n].tolist())
star_neighbor = np.array(star_neighbor)

# %%
# 기본 데이터
plt.figure(figsize=(8, 8))
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, s=100)

# 별 표시
sns.scatterplot(x=star[:,0], y=star[:,1], 
                marker='*', 
                color=star_color, 
                s=800)

# 이웃 표시
plt.scatter(x=star_neighbor[:,0], y=star_neighbor[:,1], 
            linewidth=2,
            facecolors='none', 
            color='r', 
            s=300)

plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# - 헉, 3개의 이웃이 이리도 **멀..................리** 떨어져 있었던가요???

# %% [markdown]
# # 6.정규화 후 다시 학습
#
# - 진정한 이웃을 찾기 위해 정규화를 진행하고 다시 학습합니다.

# %%
# 모듈 불러오기
from sklearn.preprocessing import MinMaxScaler

# 정규화
scaler = MinMaxScaler()
scaler.fit(x)
x = scaler.transform(x)

# 별 위치도 정규화 반영(OUR_STAR = np.array([[26, 3500]]))
star = scaler.transform(OUR_STAR)

# 다시 학습
model.fit(x, y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # 7.우리별 색깔은?
#
# - 다시 한 번 가장 가까운 3개의 이웃에게 우리별 색깔을 물었습니다.

# %%
# 기본 데이터
plt.figure(figsize=(8, 8))
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, s=100)

# 별 색깔 확인
y_pred = model.predict(star)
star_color = 'b' if y_pred == 0 else 'r'

# 별 표시
sns.scatterplot(x=star[:,0], y=star[:,1], 
                marker='*', 
                color=star_color, 
                s=800)

plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# - 오홋! 우리별은 시원한 **<font color='blue'>파란색</font>** 었네요!!

# %% [markdown]
# # 8.새로운 이웃 확인
#
# - 고마운 마음을 전하기 위해 파란색을 찾아준 이웃을 확인합니다.

# %%
# 가장 까까운 이웃 찾기
star_neighbor=[]
for n in model.kneighbors(star)[1].ravel():
    star_neighbor.append(x[n].tolist())
star_neighbor = np.array(star_neighbor)

# %%
# 기본 데이터
plt.figure(figsize=(8, 8))
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, s=100)

# 별 표시
sns.scatterplot(x=star[:,0], y=star[:,1], marker='*', color=star_color, s=800)

# 이웃 표시
plt.scatter(x=star_neighbor[:,0], 
            y=star_neighbor[:,1], 
            linewidth=2,
            facecolors='none', 
            color='r', 
            s=300)

# 원 그리기
circle = plt.Circle((star[0,0], star[0,1]), 0.100, 
                    color='k', 
                    linewidth=2,
                    linestyle='--', 
                    fill=False)
plt.gca().add_artist(circle)

plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# - 고마운 이웃이 정말 가까이 있었군요!!

# %% [markdown]
# # 9.이웃 수 늘리기
#
# - 사교 능력을 최대한 발위해 이웃 수(n_neighbors)를 5개로 늘려봅니다.

# %%
# 선언하기
model = KNeighborsClassifier(n_neighbors=5)

# 학습하기
model.fit(x, y)

# %% [markdown]
# # 10. 우리별 색깔은?
#
# - 우리별 색깔은 여전히 파란색일까요?
# - 가장 가까운 5개 이웃에게 다시 물었습니다.

# %%
# 가장 까까운 이웃 찾기
star_neighbor=[]
for n in model.kneighbors(star)[1].ravel():
    star_neighbor.append(x[n].tolist())
star_neighbor = np.array(star_neighbor)

# %%
# 기본 데이터
plt.figure(figsize=(8, 8))
sns.scatterplot(x=x[:,0], y=x[:,1], hue=y, s=100)

# 별 색깔 확인
y_pred = model.predict(star)
star_color = 'b' if y_pred == 0 else 'r'

# 별 표시
sns.scatterplot(x=star[:,0], y=star[:,1], marker='*', color=star_color, s=800)

# 이웃 표시
plt.scatter(x=star_neighbor[:,0], y=star_neighbor[:,1], 
            linewidth=2,
            facecolors='none', 
            color='r', 
            s=300)

# 원 그리기
circle = plt.Circle((star[0,0], star[0,1]), 0.17, 
                    color='k', 
                    linewidth=2, 
                    linestyle='--', 
                    fill=False)
plt.gca().add_artist(circle)

plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %% [markdown]
# - 헛! 우리별은 따뜻한 **<font color='red'>빨간색</font>** 이었군요!!! 엥?
